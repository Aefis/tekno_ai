# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
print(torch.version.cuda)
# Out:
# True
# NVIDIA GeForce RTX 5050 Laptop GPU
# 13.0

# %%
# 3. Embedding model (Hugging Face)
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

embed_model = HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2") #device="cpu"

# %%
# 6. Rechargement de l’index plus tard
from llama_index.core import load_index_from_storage
from llama_index.core import StorageContext

storage_context = StorageContext.from_defaults(persist_dir="./index_storage")
index = load_index_from_storage(storage_context, embed_model=embed_model)

# %%
# 7. Configuration du LLM Mistral (génération)
from llama_index.llms.huggingface import HuggingFaceLLM
import torch 

llm = HuggingFaceLLM(
    model_name="mistralai/Mistral-7B-Instruct-v0.3",
    tokenizer_name="mistralai/Mistral-7B-Instruct-v0.3",
    context_window=32000,
    max_new_tokens=512,
    device_map="auto",
     model_kwargs={
        "torch_dtype": torch.float16,
        "low_cpu_mem_usage": True
    }
)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.55G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# c:\Users\alaa-\miniconda3\envs\tekno\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\alaa-\.cache\huggingface\hub\models--mistralai--Mistral-7B-Instruct-v0.3. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Some parameters are on the meta device because they were offloaded to the cpu and disk.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\alaa-\miniconda3\envs\tekno\lib\site-packages\transformers\tokenization_utils_base.py:2343, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2342 try:
# -> 2343     tokenizer = cls(*init_inputs, **init_kwargs)
#    2344 except import_protobuf_decode_error():
#
# File c:\Users\alaa-\miniconda3\envs\tekno\lib\site-packages\transformers\models\llama\tokenization_llama_fast.py:154, in LlamaTokenizerFast.__init__(self, vocab_file, tokenizer_file, clean_up_tokenization_spaces, unk_token, bos_token, eos_token, add_bos_token, add_eos_token, use_default_system_prompt, legacy, add_prefix_space, **kwargs)
#     152     kwargs["from_slow"] = True
# --> 154 super().__init__(
#     155     vocab_file=vocab_file,
#     156     tokenizer_file=tokenizer_file,
#     157     clean_up_tokenization_spaces=clean_up_tokenization_spaces,
#     158     unk_token=unk_token,
#     159     bos_token=bos_token,
#     160     eos_token=eos_token,
#     161     add_bos_token=add_bos_token,
#     162     add_eos_token=add_eos_token,
#     163     use_default_system_prompt=use_default_system_prompt,
#     164     add_prefix_space=add_prefix_space,
#     165     legacy=legacy,
#     166     **kwargs,
#     167 )
#     168 self._add_bos_token = add_bos_token
#
# File c:\Users\alaa-\miniconda3\envs\tekno\lib\site-packages\transformers\tokenization_utils_fast.py:108, in PreTrainedTokenizerFast.__init__(self, *args, **kwargs)
#     107 if from_slow and slow_tokenizer is None and self.slow_tokenizer_class is None:
# --> 108     raise ValueError(
#     109         "Cannot instantiate this tokenizer from a slow version. If it's based on sentencepiece, make sure you "
#     110         "have sentencepiece installed."
#     111     )
#     113 if tokenizer_object is not None:
#
# ValueError: Cannot instantiate this tokenizer from a slow version. If it's based on sentencepiece, make sure you have sentencepiece installed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 5
#       2 from llama_index.llms.huggingface import HuggingFaceLLM
#       3 import torch
# ----> 5 llm = HuggingFaceLLM(
#       6     model_name="mistralai/Mistral-7B-Instruct-v0.3",
#       7     tokenizer_name="mistralai/Mistral-7B-Instruct-v0.3",
#       8     context_window=32000,
#       9     max_new_tokens=512,
#      10     device_map="auto",
#      11      model_kwargs={
#      12         "torch_dtype": torch.float16,
#      13         "low_cpu_mem_usage": True
#      14     }
#      15 )
#
# File c:\Users\alaa-\miniconda3\envs\tekno\lib\site-packages\llama_index\llms\huggingface\base.py:233, in HuggingFaceLLM.__init__(self, context_window, max_new_tokens, query_wrapper_prompt, tokenizer_name, model_name, model, tokenizer, device_map, stopping_ids, tokenizer_kwargs, tokenizer_outputs_to_remove, model_kwargs, generate_kwargs, is_chat_model, callback_manager, system_prompt, messages_to_prompt, completion_to_prompt, pydantic_program_mode, output_parser)
#     230 if "max_length" not in tokenizer_kwargs:
#     231     tokenizer_kwargs["max_length"] = context_window
# --> 233 tokenizer = tokenizer or AutoTokenizer.from_pretrained(
#     234     tokenizer_name, **tokenizer_kwargs
#     235 )
#     237 if tokenizer.name_or_path != model.name_or_path:
#     238     logger.warning(
#     239         f"The model `{model.name_or_path}` and tokenizer `{tokenizer.name_or_path}` "
#     240         f"are different, please ensure that they are compatible."
#     241     )
#
# File c:\Users\alaa-\miniconda3\envs\tekno\lib\site-packages\transformers\models\auto\tokenization_auto.py:1140, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#    1136     if tokenizer_class is None:
#    1137         raise ValueError(
#    1138             f"Tokenizer class {tokenizer_class_candidate} does not exist or is not currently imported."
#    1139         )
# -> 1140     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#    1142 # Otherwise we have to be creative.
#    1143 # if model is an encoder decoder, the encoder tokenizer class is used by default
#    1144 if isinstance(config, EncoderDecoderConfig):
#
# File c:\Users\alaa-\miniconda3\envs\tekno\lib\site-packages\transformers\tokenization_utils_base.py:2097, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2094     else:
#    2095         logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
# -> 2097 return cls._from_pretrained(
#    2098     resolved_vocab_files,
#    2099     pretrained_model_name_or_path,
#    2100     init_configuration,
#    2101     *init_inputs,
#    2102     token=token,
#    2103     cache_dir=cache_dir,
#    2104     local_files_only=local_files_only,
#    2105     _commit_hash=commit_hash,
#    2106     _is_local=is_local,
#    2107     trust_remote_code=trust_remote_code,
#    2108     **kwargs,
#    2109 )
#
# File c:\Users\alaa-\miniconda3\envs\tekno\lib\site-packages\transformers\tokenization_utils_base.py:2344, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2342 try:
#    2343     tokenizer = cls(*init_inputs, **init_kwargs)
# -> 2344 except import_protobuf_decode_error():
#    2345     logger.info(
#    2346         "Unable to load tokenizer model from SPM, loading from TikToken will be attempted instead."
#    2347         "(Google protobuf error: Tried to load SPM model with non-SPM vocab file).",
#    2348     )
#    2349     return False
#
# File c:\Users\alaa-\miniconda3\envs\tekno\lib\site-packages\transformers\tokenization_utils_base.py:87, in import_protobuf_decode_error(error_message)
#      85     return DecodeError
#      86 else:
# ---> 87     raise ImportError(PROTOBUF_IMPORT_ERROR.format(error_message))
#
# ImportError:
#  requires the protobuf library but it was not found in your environment. Check out the instructions on the
# installation page of its repo: https://github.com/protocolbuffers/protobuf/tree/master/python#installation and follow the ones
# that match your environment. Please note that you may need to restart your runtime after installation.

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
print(torch.version.cuda)
# Out:
# True
# NVIDIA GeForce RTX 5050 Laptop GPU
# 13.0

# %%
# 8. Moteur de requêtes RAG
query_engine = index.as_query_engine(llm=llm)

# 9. Exemple de question
response = query_engine.query("Quel .")
print(response)
